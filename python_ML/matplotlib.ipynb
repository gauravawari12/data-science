# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravawari12/data-science/blob/main/python_ML/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.random.rand(10,4)
#x
#turn it into a dataframe
df =pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.871699  0.456458  0.361633  0.382352
# 1  0.202419  0.157162  0.821305  0.021947
# 2  0.993237  0.288837  0.104044  0.228029
# 3  0.414453  0.803964  0.492600  0.665923
# 4  0.072145  0.351802  0.624215  0.446319
# 5  0.849676  0.810383  0.394563  0.713724
# 6  0.460779  0.428448  0.252661  0.536949
# 7  0.539585  0.988090  0.057220  0.908306
# 8  0.984614  0.629566  0.187532  0.265716
# 9  0.995472  0.142321  0.415729  0.231491

# %%
df.plot.bar();

# %%
df.plot(kind='bar');

# %%
 df.plot(x='a',y='b',kind='bar');

# %%
df['c'].plot.hist();

# %%
df['c'].plot.hist(bins=20);

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45bbfd45-96c7-49f5-a923-900c92d51537" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45bbfd45-96c7-49f5-a923-900c92d51537">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 13.1 heart-disease.csv to 13.1 heart-disease.csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['13.1 heart-disease.csv']))
df2
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = df2[df2['age']> 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
  over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method
over_50.plot(kind="scatter",
              x='age',
             y='chol',
             c='target',
             figsize=(10,6));

# %%
## oo method mix with pyplot methodes
fig,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax);
#ax.set_xlim([45,100])

# %%
#oo method from scratch 
fig ,ax =  plt.subplots(figsize=(10,6))
#plot the data 
scatter = ax.scatter(x=over_50['age'],
                      y=over_50['chol'],
                     c=over_50['target'])

#customize the plot
ax.set(title ='Heart Disease and cholesterol Level',
       xlabel='Age',
       ylabel='Cholesterol')
#add legend
ax.legend(*scatter.legend_elements(),title='target')

#add horizontal line 
ax.axhline(over_50['chol'].mean(), linestyle='--');

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subp;ot of chol,age, thalach[max heart rate]
fig,(ax0,ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10))

#add data to ax0
scatter = ax0.scatter(x=over_50['age'],
                      y=over_50['chol'],
                      c=over_50['target'])
ax0.set(title="Heart Disease and Cholesterol Level",
        ylabel='cholesterol')
#add a legend to ax0
ax0.legend(*scatter.legend_elements(),title='target')

#add a meanline 
ax0.axhline(y=over_50['chol'].mean(),linestyle='--')


#add data to ax1
scatter = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'])
ax1.set(title="Heart Disease and Max HeartRate Level ",
        xlabel='age',
        ylabel='thalach')
#add a legend to ax0
ax1.legend(*scatter.legend_elements(),title='target')

#add a meanline 
ax1.axhline(y=over_50['thalach'].mean(),linestyle='--')


#add a title to fig {blue box}
fig.suptitle("Heart Disease Analysis", fontsize=16,fontweight='bold');

# %% [markdown]
# # **customizing  matplotllb plots and getting stylish**

# %%
#see the different style availabel 
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
 over_50['thalach'].plot();

# %%
plt.style.use('seaborn-whitegrid')   #plot chaange  defalut to seaborn-whitegrid

# %%
 over_50['thalach'].plot();

# %%
plt.style.use('seaborn')

# %%
 over_50['thalach'].plot();

# %%
over_50.plot(kind="scatter",
              x='age',
             y='chol',
             c='target',
             figsize=(10,6));

# %%
plt.style.use('ggplot')

# %%
over_50.plot(kind="scatter",
              x='age',
             y='chol',
             c='target',
             figsize=(10,6));

# %%
#create some data 
x= np.random.randn(10,4)
x
# Out:
# array([[ 0.82657655,  1.27330744, -0.16929018, -0.58380144],
#        [ 1.55271784, -0.60902237,  0.3444891 , -0.15085452],
#        [-2.45118686, -1.06245033,  0.27089966, -0.27158658],
#        [ 3.41912992,  0.22030744, -0.59978222,  1.29627504],
#        [-0.10506695, -1.02811629,  0.23051901,  0.95485997],
#        [ 1.69076171, -0.17535223,  0.38239521,  0.06682451],
#        [-0.71018847,  0.67390038, -0.20498295, -1.02795164],
#        [-1.36510447, -0.03014636, -0.87389298,  0.01983244],
#        [ 1.62974067,  1.10930893,  0.4471152 , -0.16803875],
#        [-0.37814843, -0.66081544,  0.29525275,  0.70807328]])

# %%
df= pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.826577  1.273307 -0.169290 -0.583801
# 1  1.552718 -0.609022  0.344489 -0.150855
# 2 -2.451187 -1.062450  0.270900 -0.271587
# 3  3.419130  0.220307 -0.599782  1.296275
# 4 -0.105067 -1.028116  0.230519  0.954860
# 5  1.690762 -0.175352  0.382395  0.066825
# 6 -0.710188  0.673900 -0.204983 -1.027952
# 7 -1.365104 -0.030146 -0.873893  0.019832
# 8  1.629741  1.109309  0.447115 -0.168039
# 9 -0.378148 -0.660815  0.295253  0.708073

# %%
ax=df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
#customize our plot with set() method 
ax=df.plot(kind='bar')
#add some label and a title
ax.set(title='Random Numper Bar Graph from DataFame',
       xlabel="row number",
       ylabel='col number')
    
#make the legend visiable 
ax.legend().set_visible(True);

# %%
#set the  style   #cmap is use for color map
plt.style.use('seaborn-whitegrid')


#oo method from scratch 
fig ,ax =  plt.subplots(figsize=(10,6))
#plot the data 
scatter = ax.scatter(x=over_50['age'],jupiterhospital
                      y=over_50['chol'],
                     c=over_50['target'],
                     cmap='winter')

#customize the plot
ax.set(title ='Heart Disease and cholesterol Level',
       xlabel='Age',
       ylabel='Cholesterol')
#add legend
ax.legend(*scatter.legend_elements(),title='target')

#add horizontal line 
ax.axhline(over_50['chol'].mean(), linestyle='--');

# %%
#customizing the y and x axis limitations


# subp;ot of chol,age, thalach[max heart rate]
fig,(ax0,ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10))

#add data to ax0
scatter = ax0.scatter(x=over_50['age'],
                      y=over_50['chol'],jupiterhospital
                      c=over_50['target']
                      ,cmap="winter")
ax0.set(title="Heart Disease and Cholesterol Level",
        ylabel='cholesterol')
#add a legend to ax0
ax0.legend(*scatter.legend_elements(),title='target')

#add a meanline 
ax0.axhline(y=over_50['chol'].mean(),linestyle='--')

#change the x axis limit 
ax0.set_xlim([50,80])

#add data to ax1
scatter = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'],
                      cmap='winter')
ax1.set(title="Heart Disease and Max HeartRate Level ",
        xlabel='age',
        ylabel='thalach')
#add a legend to ax0
ax1.legend(*scatter.legend_elements(),title='target')

#add a meanline 
ax1.axhline(y=over_50['thalach'].mean(),linestyle='--')

#change the x and y axis limit 
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
#add a title to fig {blue box}
fig.suptitle("Heart Disease Analysis", fontsize=16,fontweight='bold');

# %%
fig.savefig("heart-disease-analysis-plot-with-code.png")  #to save the plot
